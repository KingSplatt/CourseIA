# %%
import numpy as np
import pandas as pd

# cargar el dataset
data = pd.read_csv('./Dataset/spam.csv', encoding='ISO-8859-1')

# eliminar las columnas que no se utilizan
data = data.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)
data
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split


# renombrar las columnas
data.columns = ['label', 'message']

# Convertir las etiquetas (ham -> 0, spam -> 1)
data['label'] = data['label'].map({'ham': 0, 'spam': 1})

# Dividir los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(data['message'], data['label'], test_size=0.2, random_state=42)


####### Aqui se entrenara el modelo


# mensajes para probar el modelo entrenado
messages = [
    "Congratulations! You've been selected as a winner. Call 123456 to claim your prize.",
    "Hey, what are you up to? Do you want to hang out later?",
    "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question (std txt rate) T&C's apply 08452810075over18's",
    "URGENT! Your mobile No 1234 was awarded a Prize",
    "Hi, how are you? I hope you're doing well."
]
# Out:
# Accuracy: 0.9838565022421525
# Confusion Matrix:
# [[959   6]
#  [ 12 138]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       965
#            1       0.96      0.92      0.94       150
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.96      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
#
# Congratulations! You've been selected as a winner. Call 123456 to claim your prize. -> spam
# Hey, what are you up to? Do you want to hang out later? -> ham
# Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question (std txt rate) T&C's apply 08452810075over18's -> spam
# URGENT! Your mobile No 1234 was awarded a Prize -> spam
# Hi, how are you? I hope you're doing well. -> ham
